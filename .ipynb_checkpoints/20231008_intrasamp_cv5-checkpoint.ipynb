# %% [markdown]
# # CV evaluation with lasso regression on PD datasets (within each dataset separately)

# %%
import os
import sys
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from multiprocessing import Pool
import warnings
import microscope as mc
import pickle

from sklearn.metrics import classification_report

sns.set_style("white")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
base_d = "/Users/erankotler/dinamo"
data_d = os.path.join(base_d, "data/gse_data_20231002")

results_d = os.path.join(base_d, "resutls")
models_d = os.path.join(base_d, "models")

# %%
[d for d in os.listdir(data_d) if d.startswith("GSE")]
# Out:
# ['GSE145361',
#  'GSE111223',
#  'GSE190348',
#  'GSE42861',
#  'GSE111942',
#  'GSE87095',
#  'GSE147221',
#  'GSE175364',
#  'GSE111629',
#  'GSE121192']

# %%
# gse_acc = "GSE111223" # PD ~260 samps
# gse_acc = "GSE111629" # PD ~570 samps
# gse_acc = "GSE145361" # PD, ~1800 samps

# %%
PD_datasets = ["GSE145361","GSE111629", "GSE190348", "GSE111223"]

RA_datasets = ["GSE42861","GSE111942","GSE121192","GSE87095"] # "GSE175364" is a 78-patient dataset for prediction of  undifferentiated arthritis (UA)=>RA progression with only 6 controls

# %%
# %%time
datasets_to_analyze = RA_datasets #PD_datasets # RA_datasets

CV_results = {}
for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    data.load_data() 
    # data.load_data(max_CpGs=50000, max_samps=200) # For debugging
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" # 10 #"LOO"
        penalty = 'l1', 
        internalCV_folds = 5,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    CV_results[gse_acc] = cv_res
    
    # save the model to disk
    out_f = os.path.join(results_d, gse_acc + "_l1_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE42861
# Target label counts (0/1): 335 / 354
# Original labels: ['case' 'control']
# Number of samples: 689
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 620, test size: 69 (fract positives in train: 0.552)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 8.6 sec
# Starting feature selection using wilcoxon
# Feature selection complete, ready for training, elapsed time: 97.3 sec
# Fold complete, fold time: 168.0 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 620, test size: 69 (fract positives in train: 0.552)
# Imputing missing values, elapsed time: 1.3 sec
# Starting feature selection, elapsed time: 9.0 sec
# Starting feature selection using wilcoxon
# Feature selection complete, ready for training, elapsed time: 99.9 sec
# Fold complete, fold time: 163.3 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 620, test size: 69 (fract positives in train: 0.508)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 8.7 sec
# Starting feature selection using wilcoxon
# Feature selection complete, ready for training, elapsed time: 99.3 sec
# Fold complete, fold time: 172.5 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 620, test size: 69 (fract positives in train: 0.529)
# Imputing missing values, elapsed time: 1.3 sec
# Starting feature selection, elapsed time: 9.1 sec
# Starting feature selection using wilcoxon
# Feature selection complete, ready for training, elapsed time: 99.0 sec
# Fold complete, fold time: 165.6 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 620, test size: 69 (fract positives in train: 0.550)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 8.7 sec
# Starting feature selection using wilcoxon

# %%
for gse_acc in list(CV_results.keys()):
    print(gse_acc)
    try:
        mc.plot_cv_roc(CV_results[gse_acc])
    except:
        print ("Cant plot ROC curve for %s (test sets don't include both labels)"%gse_acc)

# %%
for gse_acc in list(CV_results.keys()):
    print(gse_acc)
    try:
        mc.plot_cv_roc(CV_results[gse_acc])
    except:
        print ("Cant plot ROC curve for %s (test sets don't include both labels)"%gse_acc)
# Out:
# GSE42861
# GSE111942
# Cant plot ROC curve for GSE111942 (test sets don't include both labels)
# GSE121192
# Cant plot ROC curve for GSE121192 (test sets don't include both labels)
# GSE87095

# %%
for gse_acc in list(CV_results.keys()):
    print(gse_acc)
    try:
        mc.plot_cv_roc(CV_results[gse_acc])
    except:
        print ("Cant plot ROC curve for %s (test sets don't include both labels)"%gse_acc)
# Out:
# GSE42861
# GSE111942
# GSE121192
# GSE87095

# %%
cv_res = CV_results["GSE42861"]

# %%
cv_res[

# %%
THRESH = 0.7
for gse_acc in list(CV_results.keys()):
    print(gse_acc)
    mc.print_report(cv_res=CV_results[gse_acc], THRESH=THRESH)
    mc.plot_pred_prob_by_labels(cv_res=CV_results[gse_acc])
    print("******************************************************\n")
# Out:
# GSE42861
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.45      0.50       335
#          1.0       0.56      0.65      0.60       354
#
#     accuracy                           0.56       689
#    macro avg       0.56      0.55      0.55       689
# weighted avg       0.56      0.56      0.55       689
# ******************************************************
#
# GSE111942
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.56      0.38        18
#          1.0       0.00      0.00      0.00        25
#
#     accuracy                           0.23        43
#    macro avg       0.14      0.28      0.19        43
# weighted avg       0.12      0.23      0.16        43
# ******************************************************
#
# GSE121192
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        16
#          1.0       0.65      1.00      0.79        30
#
#     accuracy                           0.65        46
#    macro avg       0.33      0.50      0.39        46
# weighted avg       0.43      0.65      0.51        46
# /Users/erankotler/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/erankotler/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/erankotler/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ******************************************************
#
# GSE87095
#               precision    recall  f1-score   support
#
#          0.0       0.60      1.00      0.75        73
#          1.0       0.00      0.00      0.00        49
#
#     accuracy                           0.60       122
#    macro avg       0.30      0.50      0.37       122
# weighted avg       0.36      0.60      0.45       122
# /Users/erankotler/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/erankotler/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/erankotler/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ******************************************************

# %%
gse_acc = "GSE42861" #"GSE175364"#"GSE111223"#
gse_d = os.path.join(data_d, gse_acc)

data = mc.Dataset(gse_d=gse_d)
data.load_data()#max_CpGs=500, max_samps=50) 
data.organize_data()

data.groups.value_counts()
# Out:
# Target label counts (0/1): 335 / 354
# Group
# case       354
# control    335
# Name: count, dtype: int64

# %%
df = data.df

# %%
df.shape
# Out:
# (689, 486427)

# %%
df = df.dropna(how="all", axis=1)

# %%
df.shape
# Out:
# (689, 421560)

# %%
# %%time
imp_vals = mc.feature_imputation_values(df, nan_policy="zeros")

# %%
imp_vals.head()

# %%
# %%time
imp_vals = mc.feature_imputation_values(df, nan_policy='impute_by_median')
# Out:
# CPU times: user 7.2 s, sys: 295 ms, total: 7.49 s
# Wall time: 7.49 s

# %%
from numba import njit

# %%
def fillna_npwhere_njit(array, values):
    """ Speed-optimized df.fillna() function (solution taken from https://www.kaggle.com/code/gogo827jz/optimise-speed-of-filling-nan-function)"""
    if np.isnan(array.sum()):
        array = np.where(np.isnan(array), values, array)
    return array

# %%
def numba_fillna(array, values):
    """ Speed-optimized df.fillna() function (solution taken from https://www.kaggle.com/code/gogo827jz/optimise-speed-of-filling-nan-function)"""
    if np.isnan(array.sum()):
        array = np.where(np.isnan(array), values, array)
    return array

# %%
# %%time
df1 = pd.DataFrame(data=numba_fillna(df.values, imp_vals.values),
                  index=df.index, columns=df.columns)
# Out:
# CPU times: user 291 ms, sys: 191 ms, total: 482 ms
# Wall time: 490 ms

# %%
df.head()
# Out:
#             cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# GSM1051525    0.686281    0.962046    0.905875    0.193567    0.817305
# GSM1051526    0.584531    0.967548    0.888333    0.178298    0.818665
# GSM1051527    0.592709    0.975919    0.919231    0.188164    0.834525
# GSM1051528    0.577408    0.963163    0.926322    0.232448    0.831883
# GSM1051529    0.640440    0.966132    0.917095    0.211572    0.866477
#
#             cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# GSM1051525         NaN    0.906231    0.260223    0.340059    0.016046  ...
# GSM1051526         NaN    0.891455    0.278688    0.364477    0.016934  ...
# GSM1051527         NaN    0.852248    0.257025    0.327229    0.013867  ...
# GSM1051528         NaN    0.887470    0.247310    0.361641    0.014647  ...
# GSM1051529         NaN    0.855370    0.263623    0.320598    0.015495  ...
#
#             rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# GSM1051525   0.024458  0.427357  0.438267  0.019204   0.498311   0.041816
# GSM1051526   0.977473  0.416408  0.933439  0.019222   0.514895   0.504683
# GSM1051527   0.477089  0.440854  0.430473  0.980047   0.512881   0.504845
# GSM1051528   0.979112  0.429853  0.448298  0.505598   0.968937   0.523901
# GSM1051529   0.475986  0.418893  0.059563  0.021861   0.021292   0.966994
#
#             rs939290  rs951295  rs966367  rs9839873
# GSM1051525  0.539630  0.971805  0.058699   0.944050
# GSM1051526  0.967514  0.510694  0.937656   0.949624
# GSM1051527  0.970910  0.080963  0.949168   0.954501
# GSM1051528  0.558666  0.971480  0.941798   0.660119
# GSM1051529  0.533191  0.523817  0.936594   0.942595
#
# [5 rows x 421560 columns]

# %%
df1.head()
# Out:
#             cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# GSM1051525    0.686281    0.962046    0.905875    0.193567    0.817305
# GSM1051526    0.584531    0.967548    0.888333    0.178298    0.818665
# GSM1051527    0.592709    0.975919    0.919231    0.188164    0.834525
# GSM1051528    0.577408    0.963163    0.926322    0.232448    0.831883
# GSM1051529    0.640440    0.966132    0.917095    0.211572    0.866477
#
#             cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# GSM1051525    0.775707    0.906231    0.260223    0.340059    0.016046  ...
# GSM1051526    0.775707    0.891455    0.278688    0.364477    0.016934  ...
# GSM1051527    0.775707    0.852248    0.257025    0.327229    0.013867  ...
# GSM1051528    0.775707    0.887470    0.247310    0.361641    0.014647  ...
# GSM1051529    0.775707    0.855370    0.263623    0.320598    0.015495  ...
#
#             rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# GSM1051525   0.024458  0.427357  0.438267  0.019204   0.498311   0.041816
# GSM1051526   0.977473  0.416408  0.933439  0.019222   0.514895   0.504683
# GSM1051527   0.477089  0.440854  0.430473  0.980047   0.512881   0.504845
# GSM1051528   0.979112  0.429853  0.448298  0.505598   0.968937   0.523901
# GSM1051529   0.475986  0.418893  0.059563  0.021861   0.021292   0.966994
#
#             rs939290  rs951295  rs966367  rs9839873
# GSM1051525  0.539630  0.971805  0.058699   0.944050
# GSM1051526  0.967514  0.510694  0.937656   0.949624
# GSM1051527  0.970910  0.080963  0.949168   0.954501
# GSM1051528  0.558666  0.971480  0.941798   0.660119
# GSM1051529  0.533191  0.523817  0.936594   0.942595
#
# [5 rows x 421560 columns]

# %%
# %%time
df = df.fillna(imp_vals)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/generic.py:7250, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7247 res_k = result[k].fillna(v, limit=limit, downcast=downcast_k)
#    7249 if not inplace:
# -> 7250     result[k] = res_k
#    7251 else:
#    7252     # We can write into our existing column(s) iff dtype
#    7253     #  was preserved.
#    7254     if isinstance(res_k, ABCSeries):
#    7255         # i.e. 'k' only shows up once in self.columns
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/frame.py:4317, in DataFrame._set_item(self, key, value)
#    4314             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4315             refs = None
# -> 4317 self._set_item_mgr(key, value, refs)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/frame.py:4269, in DataFrame._set_item_mgr(self, key, value, refs)
#    4267     self._mgr.insert(len(self._info_axis), key, value, refs)
#    4268 else:
# -> 4269     self._iset_item_mgr(loc, value, refs=refs)
#    4271 # check if we are modifying a copy
#    4272 # try to set first as we want an invalid
#    4273 # value exception to occur first
#    4274 if len(self):
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/frame.py:4257, in DataFrame._iset_item_mgr(self, loc, value, inplace, refs)
#    4249 def _iset_item_mgr(
#    4250     self,
#    4251     loc: int | slice | np.ndarray,
#    (...)
#    4255 ) -> None:
#    4256     # when called from _set_item_mgr loc can be anything returned from get_loc
# -> 4257     self._mgr.iset(loc, value, inplace=inplace, refs=refs)
#    4258     self._clear_item_cache()
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/internals/managers.py:1139, in BlockManager.iset(self, loc, value, inplace, refs)
#    1136             continue
#    1137         else:
#    1138             # Defer setting the new values to enable consolidation
# -> 1139             self._iset_split_block(blkno_l, blk_locs, refs=refs)
#    1141 if len(removed_blknos):
#    1142     # Remove blocks & update blknos accordingly
#    1143     is_deleted = np.zeros(self.nblocks, dtype=np.bool_)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/internals/managers.py:1240, in BlockManager._iset_split_block(self, blkno_l, blk_locs, value, refs)
#    1236 if not nbs_tup and value is not None:
#    1237     # No need to update anything if split did not happen
#    1238     return
# -> 1240 self._blklocs[first_nb.mgr_locs.indexer] = np.arange(len(first_nb))
#    1242 for i, nb in enumerate(nbs_tup):
#    1243     self._blklocs[nb.mgr_locs.indexer] = np.arange(len(nb))
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/core/internals/blocks.py:293, in Block.__len__(self)
#     289         result = f"{name}: {self.mgr_locs.indexer}, {shape}, dtype: {self.dtype}"
#     291     return result
# --> 293 @final
#     294 def __len__(self) -> int:
#     295     return len(self.values)
#     297 @final
#     298 def slice_block_columns(self, slc: slice) -> Self:
#
# KeyboardInterrupt:

# %%
df.shape
# Out:
# (689, 421560)

# %%
df
# Out:
#             cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# GSM1051525    0.686281    0.962046    0.905875    0.193567    0.817305
# GSM1051526    0.584531    0.967548    0.888333    0.178298    0.818665
# GSM1051527    0.592709    0.975919    0.919231    0.188164    0.834525
# GSM1051528    0.577408    0.963163    0.926322    0.232448    0.831883
# GSM1051529    0.640440    0.966132    0.917095    0.211572    0.866477
# ...                ...         ...         ...         ...         ...
# GSM1052209    0.592203    0.954109    0.904882    0.219661    0.827999
# GSM1052210    0.678658    0.667800         NaN         NaN         NaN
# GSM1052211    0.535610    0.963002    0.914095    0.154860    0.874325
# GSM1052212    0.492007    0.961565    0.893053    0.155948    0.848837
# GSM1052213    0.581974    0.938243    0.918854    0.166697    0.857047
#
#             cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# GSM1051525         NaN    0.906231    0.260223    0.340059    0.016046  ...
# GSM1051526         NaN    0.891455    0.278688    0.364477    0.016934  ...
# GSM1051527         NaN    0.852248    0.257025    0.327229    0.013867  ...
# GSM1051528         NaN    0.887470    0.247310    0.361641    0.014647  ...
# GSM1051529         NaN    0.855370    0.263623    0.320598    0.015495  ...
# ...                ...         ...         ...         ...         ...  ...
# GSM1052209    0.752372    0.891825    0.356841    0.367995    0.014949  ...
# GSM1052210         NaN    0.948284    0.307975    0.179352    0.015159  ...
# GSM1052211    0.791451    0.882077    0.272573    0.383886    0.019115  ...
# GSM1052212         NaN    0.901595    0.293819    0.439254    0.016573  ...
# GSM1052213         NaN    0.873044    0.306228    0.369147    0.015079  ...
#
#             rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# GSM1051525   0.024458  0.427357  0.438267  0.019204   0.498311   0.041816
# GSM1051526   0.977473  0.416408  0.933439  0.019222   0.514895   0.504683
# GSM1051527   0.477089  0.440854  0.430473  0.980047   0.512881   0.504845
# GSM1051528   0.979112  0.429853  0.448298  0.505598   0.968937   0.523901
# GSM1051529   0.475986  0.418893  0.059563  0.021861   0.021292   0.966994
# ...               ...       ...       ...       ...        ...        ...
# GSM1052209   0.032457  0.456806  0.933303  0.977614   0.502663   0.046552
# GSM1052210   0.961334  0.979819       NaN  0.123634   0.967231   0.903874
# GSM1052211   0.516712  0.451783  0.931258  0.555527   0.508514   0.042947
# GSM1052212   0.974069  0.978421  0.459357  0.979481   0.514862   0.962780
# GSM1052213   0.042364  0.443068  0.470930  0.029451   0.025383   0.954086
#
#             rs939290  rs951295  rs966367  rs9839873
# GSM1051525  0.539630  0.971805  0.058699   0.944050
# GSM1051526  0.967514  0.510694  0.937656   0.949624
# GSM1051527  0.970910  0.080963  0.949168   0.954501
# GSM1051528  0.558666  0.971480  0.941798   0.660119
# GSM1051529  0.533191  0.523817  0.936594   0.942595
# ...              ...       ...       ...        ...
# GSM1052209  0.553624  0.508093  0.614277   0.736908
# GSM1052210  0.950816  0.042149       NaN        NaN
# GSM1052211  0.537339  0.524839  0.571093   0.726644
# GSM1052212  0.546528  0.514195  0.552083   0.772179
# GSM1052213  0.566192  0.047955  0.597181   0.932744
#
# [689 rows x 421560 columns]

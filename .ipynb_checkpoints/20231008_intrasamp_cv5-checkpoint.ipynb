# %% [markdown]
# # CV evaluation with lasso regression on RA & PD datasets (within each dataset separately)

# %%
import os
import sys
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from multiprocessing import Pool
import warnings
import microscope as mc
import pickle

from sklearn.metrics import classification_report

sns.set_style("white")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
base_d = "/Users/erankotler/dinamo"
data_d = os.path.join(base_d, "data/gse_data_20231002")

results_d = os.path.join(base_d, "resutls")
models_d = os.path.join(base_d, "models")

# %%
[d for d in os.listdir(data_d) if d.startswith("GSE")]
# Out:
# ['GSE145361',
#  'GSE111223',
#  'GSE190348',
#  'GSE42861',
#  'GSE111942',
#  'GSE87095',
#  'GSE147221',
#  'GSE175364',
#  'GSE111629',
#  'GSE121192']

# %%
# gse_acc = "GSE111223" # PD ~260 samps
# gse_acc = "GSE111629" # PD ~570 samps
# gse_acc = "GSE145361" # PD, ~1800 samps

PD_datasets = ["GSE145361","GSE111629", "GSE190348", "GSE111223"]
RA_datasets = ["GSE42861","GSE111942","GSE121192","GSE87095"] # "GSE175364" is a 78-patient dataset for prediction of  undifferentiated arthritis (UA)=>RA progression with only 6 controls

# %%
# %%time
datasets_to_analyze = RA_datasets #PD_datasets # RA_datasets
RA_CV_results_l1 = {}

for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    data.load_data() 
    # data.load_data(max_CpGs=50000)#, max_samps=200) # For debugging
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" # 10 #"LOO"
        penalty = 'l1', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    RA_CV_results_l1[gse_acc] = cv_res
    
    # save results to disk
    out_f = os.path.join(results_d, gse_acc + "_l1_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE42861
# Target label counts (0/1): 335 / 354
# Original labels: ['control' 'case']
# Number of samples: 689
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 620, test size: 69 (fract positives in train: 0.518)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 5.8 sec
# Selecting features using wilcoxon
# Retained 188275 features
# Feature selection complete, ready for training, elapsed time: 73.1 sec
# Fold complete, fold time: 113.2 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 620, test size: 69 (fract positives in train: 0.523)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.3 sec
# Selecting features using wilcoxon
# Retained 197843 features
# Feature selection complete, ready for training, elapsed time: 76.9 sec
# Fold complete, fold time: 118.8 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 620, test size: 69 (fract positives in train: 0.510)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 5.9 sec
# Selecting features using wilcoxon
# Retained 189195 features
# Feature selection complete, ready for training, elapsed time: 73.6 sec
# Fold complete, fold time: 112.7 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 620, test size: 69 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 191533 features
# Feature selection complete, ready for training, elapsed time: 73.6 sec
# Fold complete, fold time: 113.0 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 620, test size: 69 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 189704 features
# Feature selection complete, ready for training, elapsed time: 73.9 sec
# Fold complete, fold time: 113.4 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 620, test size: 69 (fract positives in train: 0.503)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 187053 features
# Feature selection complete, ready for training, elapsed time: 74.2 sec
# Fold complete, fold time: 114.8 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 620, test size: 69 (fract positives in train: 0.513)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 6.0 sec
# Selecting features using wilcoxon
# Retained 189820 features
# Feature selection complete, ready for training, elapsed time: 73.5 sec
# Fold complete, fold time: 113.3 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 620, test size: 69 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 188344 features
# Feature selection complete, ready for training, elapsed time: 73.8 sec
# Fold complete, fold time: 112.5 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 620, test size: 69 (fract positives in train: 0.519)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 190576 features
# Feature selection complete, ready for training, elapsed time: 73.9 sec
# Fold complete, fold time: 112.6 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 621, test size: 68 (fract positives in train: 0.509)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 6.0 sec
# Selecting features using wilcoxon
# Retained 187853 features
# Feature selection complete, ready for training, elapsed time: 73.5 sec
# Fold complete, fold time: 112.0 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE42861_l1_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE111942
# Target label counts (0/1): 18 / 25
# Original labels: ['control' 'case']
# Number of samples: 43
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 38, test size: 5 (fract positives in train: 0.632)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 55357 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 18.2 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 38, test size: 5 (fract positives in train: 0.553)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 43126 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 17.9 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 38, test size: 5 (fract positives in train: 0.579)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 52287 features
# Feature selection complete, ready for training, elapsed time: 16.4 sec
# Fold complete, fold time: 17.8 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 39, test size: 4 (fract positives in train: 0.564)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 67554 features
# Feature selection complete, ready for training, elapsed time: 16.4 sec
# Fold complete, fold time: 18.0 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 49641 features
# Feature selection complete, ready for training, elapsed time: 16.6 sec
# Fold complete, fold time: 18.1 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 45121 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 17.5 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 52789 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 17.8 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 51559 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 17.7 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 39, test size: 4 (fract positives in train: 0.538)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 76155 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 18.6 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 50946 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 17.6 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE111942_l1_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE121192
# Target label counts (0/1): 16 / 30
# Original labels: ['case' 'control']
# Number of samples: 46
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 41, test size: 5 (fract positives in train: 0.634)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 33655 features
# Feature selection complete, ready for training, elapsed time: 13.4 sec
# Fold complete, fold time: 14.1 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 41, test size: 5 (fract positives in train: 0.634)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 32278 features
# Feature selection complete, ready for training, elapsed time: 12.7 sec
# Fold complete, fold time: 13.3 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 41, test size: 5 (fract positives in train: 0.683)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 32539 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 13.5 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 41, test size: 5 (fract positives in train: 0.659)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 36739 features
# Feature selection complete, ready for training, elapsed time: 13.2 sec
# Fold complete, fold time: 14.0 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 41, test size: 5 (fract positives in train: 0.683)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 36339 features
# Feature selection complete, ready for training, elapsed time: 12.7 sec
# Fold complete, fold time: 13.4 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 41, test size: 5 (fract positives in train: 0.659)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 30728 features
# Feature selection complete, ready for training, elapsed time: 12.7 sec
# Fold complete, fold time: 13.3 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 42, test size: 4 (fract positives in train: 0.667)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 35236 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 13.5 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 42, test size: 4 (fract positives in train: 0.619)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 34413 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 13.5 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 42, test size: 4 (fract positives in train: 0.643)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 36990 features
# Feature selection complete, ready for training, elapsed time: 12.7 sec
# Fold complete, fold time: 13.5 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 42, test size: 4 (fract positives in train: 0.643)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 36403 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 13.6 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE121192_l1_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE87095
# Target label counts (0/1): 73 / 49
# Original labels: ['control' 'case']
# Number of samples: 122
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 109, test size: 13 (fract positives in train: 0.413)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.7 sec
# Selecting features using wilcoxon
# Retained 30619 features
# Feature selection complete, ready for training, elapsed time: 18.3 sec
# Fold complete, fold time: 19.6 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 109, test size: 13 (fract positives in train: 0.394)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 46680 features
# Feature selection complete, ready for training, elapsed time: 18.2 sec
# Fold complete, fold time: 20.3 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 110, test size: 12 (fract positives in train: 0.409)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 40868 features
# Feature selection complete, ready for training, elapsed time: 18.1 sec
# Fold complete, fold time: 20.1 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.1 sec
# Selecting features using wilcoxon
# Retained 36930 features
# Feature selection complete, ready for training, elapsed time: 19.4 sec
# Fold complete, fold time: 21.1 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 110, test size: 12 (fract positives in train: 0.409)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 32670 features
# Feature selection complete, ready for training, elapsed time: 18.1 sec
# Fold complete, fold time: 19.5 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 110, test size: 12 (fract positives in train: 0.418)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 43130 features
# Feature selection complete, ready for training, elapsed time: 18.3 sec
# Fold complete, fold time: 21.0 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.7 sec
# Selecting features using wilcoxon
# Retained 39969 features
# Feature selection complete, ready for training, elapsed time: 18.5 sec
# Fold complete, fold time: 20.3 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.0 sec
# Selecting features using wilcoxon
# Retained 29825 features
# Feature selection complete, ready for training, elapsed time: 18.5 sec
# Fold complete, fold time: 19.9 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 1.9 sec
# Selecting features using wilcoxon
# Retained 41791 features
# Feature selection complete, ready for training, elapsed time: 18.6 sec
# Fold complete, fold time: 20.4 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 110, test size: 12 (fract positives in train: 0.409)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 39377 features
# Feature selection complete, ready for training, elapsed time: 18.2 sec
# Fold complete, fold time: 19.9 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE87095_l1_cv_res_v0.dat
# ***************************************************************************
#
# CPU times: user 21min 27s, sys: 54.5 s, total: 22min 21s
# Wall time: 28min 5s

# %%
# %%time
datasets_to_analyze = RA_datasets #PD_datasets # RA_datasets
RA_CV_results_l2 = {}

for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    data.load_data() 
    # data.load_data(max_CpGs=50000, max_samps=200) # For debugging
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" # 10 #"LOO"
        penalty = 'l2', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    RA_CV_results_l2[gse_acc] = cv_res
    
    # save results to disk
    out_f = os.path.join(results_d, gse_acc + "_l2_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE42861
# Target label counts (0/1): 335 / 354
# Original labels: ['control' 'case']
# Number of samples: 689
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 620, test size: 69 (fract positives in train: 0.518)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 6.3 sec
# Selecting features using wilcoxon
# Retained 188275 features
# Feature selection complete, ready for training, elapsed time: 74.9 sec
# Fold complete, fold time: 147.6 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 620, test size: 69 (fract positives in train: 0.523)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 6.5 sec
# Selecting features using wilcoxon
# Retained 197843 features
# Feature selection complete, ready for training, elapsed time: 78.1 sec
# Fold complete, fold time: 155.6 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 620, test size: 69 (fract positives in train: 0.510)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.2 sec
# Selecting features using wilcoxon
# Retained 189195 features
# Feature selection complete, ready for training, elapsed time: 74.2 sec
# Fold complete, fold time: 139.9 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 620, test size: 69 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 191533 features
# Feature selection complete, ready for training, elapsed time: 73.6 sec
# Fold complete, fold time: 144.2 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 620, test size: 69 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.2 sec
# Selecting features using wilcoxon
# Retained 189704 features
# Feature selection complete, ready for training, elapsed time: 73.7 sec
# Fold complete, fold time: 139.2 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 620, test size: 69 (fract positives in train: 0.503)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.2 sec
# Selecting features using wilcoxon
# Retained 187053 features
# Feature selection complete, ready for training, elapsed time: 73.6 sec
# Fold complete, fold time: 133.5 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 620, test size: 69 (fract positives in train: 0.513)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.2 sec
# Selecting features using wilcoxon
# Retained 189820 features
# Feature selection complete, ready for training, elapsed time: 73.3 sec
# Fold complete, fold time: 137.9 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 620, test size: 69 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 188344 features
# Feature selection complete, ready for training, elapsed time: 73.6 sec
# Fold complete, fold time: 138.8 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 620, test size: 69 (fract positives in train: 0.519)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.1 sec
# Selecting features using wilcoxon
# Retained 190576 features
# Feature selection complete, ready for training, elapsed time: 73.2 sec
# Fold complete, fold time: 141.7 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 621, test size: 68 (fract positives in train: 0.509)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 6.2 sec
# Selecting features using wilcoxon
# Retained 187853 features
# Feature selection complete, ready for training, elapsed time: 73.5 sec
# Fold complete, fold time: 135.3 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE42861_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE111942
# Target label counts (0/1): 18 / 25
# Original labels: ['control' 'case']
# Number of samples: 43
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 38, test size: 5 (fract positives in train: 0.632)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 55357 features
# Feature selection complete, ready for training, elapsed time: 16.3 sec
# Fold complete, fold time: 31.1 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 38, test size: 5 (fract positives in train: 0.553)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 43126 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 30.4 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 38, test size: 5 (fract positives in train: 0.579)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 52287 features
# Feature selection complete, ready for training, elapsed time: 16.3 sec
# Fold complete, fold time: 29.8 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 39, test size: 4 (fract positives in train: 0.564)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 67554 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 32.6 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 49641 features
# Feature selection complete, ready for training, elapsed time: 16.6 sec
# Fold complete, fold time: 30.9 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 45121 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 30.7 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 52789 features
# Feature selection complete, ready for training, elapsed time: 16.6 sec
# Fold complete, fold time: 32.3 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 51559 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 30.7 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 39, test size: 4 (fract positives in train: 0.538)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 76155 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 32.6 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 39, test size: 4 (fract positives in train: 0.590)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.8 sec
# Selecting features using wilcoxon
# Retained 50946 features
# Feature selection complete, ready for training, elapsed time: 16.4 sec
# Fold complete, fold time: 31.6 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE111942_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE121192
# Target label counts (0/1): 16 / 30
# Original labels: ['case' 'control']
# Number of samples: 46
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 41, test size: 5 (fract positives in train: 0.634)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 33655 features
# Feature selection complete, ready for training, elapsed time: 13.4 sec
# Fold complete, fold time: 26.8 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 41, test size: 5 (fract positives in train: 0.634)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 32278 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 26.7 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 41, test size: 5 (fract positives in train: 0.683)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 32539 features
# Feature selection complete, ready for training, elapsed time: 12.7 sec
# Fold complete, fold time: 26.3 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 41, test size: 5 (fract positives in train: 0.659)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 36739 features
# Feature selection complete, ready for training, elapsed time: 13.1 sec
# Fold complete, fold time: 27.5 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 41, test size: 5 (fract positives in train: 0.683)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 36339 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 27.4 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 41, test size: 5 (fract positives in train: 0.659)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.6 sec
# Selecting features using wilcoxon
# Retained 30728 features
# Feature selection complete, ready for training, elapsed time: 12.6 sec
# Fold complete, fold time: 26.6 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 42, test size: 4 (fract positives in train: 0.667)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 35236 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 26.5 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 42, test size: 4 (fract positives in train: 0.619)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 34413 features
# Feature selection complete, ready for training, elapsed time: 12.9 sec
# Fold complete, fold time: 26.4 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 42, test size: 4 (fract positives in train: 0.643)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 36990 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 26.8 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 42, test size: 4 (fract positives in train: 0.643)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.7 sec
# Selecting features using wilcoxon
# Retained 36403 features
# Feature selection complete, ready for training, elapsed time: 12.8 sec
# Fold complete, fold time: 26.1 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE121192_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE87095
# Target label counts (0/1): 73 / 49
# Original labels: ['control' 'case']
# Number of samples: 122
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 109, test size: 13 (fract positives in train: 0.413)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 30619 features
# Feature selection complete, ready for training, elapsed time: 17.9 sec
# Fold complete, fold time: 35.3 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 109, test size: 13 (fract positives in train: 0.394)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 46680 features
# Feature selection complete, ready for training, elapsed time: 18.1 sec
# Fold complete, fold time: 36.3 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 110, test size: 12 (fract positives in train: 0.409)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 40868 features
# Feature selection complete, ready for training, elapsed time: 18.1 sec
# Fold complete, fold time: 36.6 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.7 sec
# Selecting features using wilcoxon
# Retained 36930 features
# Feature selection complete, ready for training, elapsed time: 18.9 sec
# Fold complete, fold time: 37.6 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 110, test size: 12 (fract positives in train: 0.409)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 32670 features
# Feature selection complete, ready for training, elapsed time: 17.9 sec
# Fold complete, fold time: 36.0 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 110, test size: 12 (fract positives in train: 0.418)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 43130 features
# Feature selection complete, ready for training, elapsed time: 18.1 sec
# Fold complete, fold time: 37.1 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.1 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 39969 features
# Feature selection complete, ready for training, elapsed time: 18.2 sec
# Fold complete, fold time: 37.5 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.7 sec
# Selecting features using wilcoxon
# Retained 29825 features
# Feature selection complete, ready for training, elapsed time: 18.0 sec
# Fold complete, fold time: 35.9 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 110, test size: 12 (fract positives in train: 0.391)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 41791 features
# Feature selection complete, ready for training, elapsed time: 18.0 sec
# Fold complete, fold time: 37.3 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 110, test size: 12 (fract positives in train: 0.409)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.6 sec
# Selecting features using wilcoxon
# Retained 39377 features
# Feature selection complete, ready for training, elapsed time: 18.1 sec
# Fold complete, fold time: 36.2 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE87095_l2_cv_res_v0.dat
# ***************************************************************************
#
# CPU times: user 2h 9min 52s, sys: 1h 1min 25s, total: 3h 11min 18s
# Wall time: 39min 52s

# %%
# %%time
datasets_to_analyze = PD_datasets # RA_datasets
PD_CV_results_l1 = {}

for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    # data.load_data() 
    data.load_data(max_samps=600) # For debugging max_CpGs=50000, 
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" # 10 #"LOO"
        penalty = 'l1', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    PD_CV_results_l1[gse_acc] = cv_res
    
    # save results to disk
    out_f = os.path.join(results_d, gse_acc + "_l2_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE145361
# Target label counts (0/1): 287 / 313
# Original labels: ['control' 'case']
# Number of samples: 600
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 540, test size: 60 (fract positives in train: 0.520)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 14.2 sec
# Selecting features using wilcoxon
# Retained 113827 features
# Feature selection complete, ready for training, elapsed time: 105.8 sec
# Fold complete, fold time: 128.2 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 540, test size: 60 (fract positives in train: 0.530)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 14.4 sec
# Selecting features using wilcoxon
# Retained 106047 features
# Feature selection complete, ready for training, elapsed time: 106.3 sec
# Fold complete, fold time: 125.1 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 540, test size: 60 (fract positives in train: 0.530)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 91479 features
# Feature selection complete, ready for training, elapsed time: 105.4 sec
# Fold complete, fold time: 121.6 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 540, test size: 60 (fract positives in train: 0.517)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 14.0 sec
# Selecting features using wilcoxon
# Retained 109778 features
# Feature selection complete, ready for training, elapsed time: 105.5 sec
# Fold complete, fold time: 125.8 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 540, test size: 60 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 1.1 sec
# Starting feature selection, elapsed time: 14.1 sec
# Selecting features using wilcoxon
# Retained 98365 features
# Feature selection complete, ready for training, elapsed time: 105.5 sec
# Fold complete, fold time: 123.2 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 540, test size: 60 (fract positives in train: 0.522)
# Imputing missing values, elapsed time: 1.1 sec
# Starting feature selection, elapsed time: 14.0 sec
# Selecting features using wilcoxon
# Retained 94332 features
# Feature selection complete, ready for training, elapsed time: 105.8 sec
# Fold complete, fold time: 122.0 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 540, test size: 60 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 106926 features
# Feature selection complete, ready for training, elapsed time: 105.3 sec
# Fold complete, fold time: 123.6 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 540, test size: 60 (fract positives in train: 0.522)
# Imputing missing values, elapsed time: 1.1 sec
# Starting feature selection, elapsed time: 14.0 sec
# Selecting features using wilcoxon
# Retained 96658 features
# Feature selection complete, ready for training, elapsed time: 105.4 sec
# Fold complete, fold time: 122.8 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 540, test size: 60 (fract positives in train: 0.522)
# Imputing missing values, elapsed time: 1.1 sec
# Starting feature selection, elapsed time: 14.0 sec
# Selecting features using wilcoxon
# Retained 124923 features
# Feature selection complete, ready for training, elapsed time: 105.6 sec
# Fold complete, fold time: 129.5 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 540, test size: 60 (fract positives in train: 0.524)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 106043 features
# Feature selection complete, ready for training, elapsed time: 105.8 sec
# Fold complete, fold time: 125.9 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE145361_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE111629
# Unable to load requested number of samples, loading entire dataset
# Target label counts (0/1): 237 / 334
# Original labels: ['case' 'control']
# Number of samples: 571
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 513, test size: 58 (fract positives in train: 0.579)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 9.5 sec
# Selecting features using wilcoxon
# Retained 47921 features
# Feature selection complete, ready for training, elapsed time: 61.3 sec
# Fold complete, fold time: 68.6 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 514, test size: 57 (fract positives in train: 0.586)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 8.2 sec
# Selecting features using wilcoxon
# Retained 46209 features
# Feature selection complete, ready for training, elapsed time: 50.9 sec
# Fold complete, fold time: 58.6 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 514, test size: 57 (fract positives in train: 0.589)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 8.0 sec
# Selecting features using wilcoxon
# Retained 44815 features
# Feature selection complete, ready for training, elapsed time: 50.7 sec
# Fold complete, fold time: 57.9 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 514, test size: 57 (fract positives in train: 0.574)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 8.2 sec
# Selecting features using wilcoxon
# Retained 42573 features
# Feature selection complete, ready for training, elapsed time: 51.9 sec
# Fold complete, fold time: 58.8 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 514, test size: 57 (fract positives in train: 0.593)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.8 sec
# Selecting features using wilcoxon
# Retained 37394 features
# Feature selection complete, ready for training, elapsed time: 50.9 sec
# Fold complete, fold time: 56.7 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 514, test size: 57 (fract positives in train: 0.564)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 47513 features
# Feature selection complete, ready for training, elapsed time: 50.4 sec
# Fold complete, fold time: 57.5 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 514, test size: 57 (fract positives in train: 0.589)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.8 sec
# Selecting features using wilcoxon
# Retained 41083 features
# Feature selection complete, ready for training, elapsed time: 50.6 sec
# Fold complete, fold time: 56.5 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 514, test size: 57 (fract positives in train: 0.591)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 8.0 sec
# Selecting features using wilcoxon
# Retained 44499 features
# Feature selection complete, ready for training, elapsed time: 50.9 sec
# Fold complete, fold time: 57.9 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 514, test size: 57 (fract positives in train: 0.591)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 8.0 sec
# Selecting features using wilcoxon
# Retained 43317 features
# Feature selection complete, ready for training, elapsed time: 50.8 sec
# Fold complete, fold time: 57.6 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 514, test size: 57 (fract positives in train: 0.591)
# Imputing missing values, elapsed time: 0.8 sec
# Starting feature selection, elapsed time: 8.1 sec
# Selecting features using wilcoxon
# Retained 44186 features
# Feature selection complete, ready for training, elapsed time: 51.6 sec
# Fold complete, fold time: 58.1 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE111629_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE190348
# Unable to load requested number of samples, loading entire dataset
# Target label counts (0/1): 16 / 15
# Original labels: ['case' 'control']
# Number of samples: 31
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 27, test size: 4 (fract positives in train: 0.444)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 263659 features
# Feature selection complete, ready for training, elapsed time: 26.7 sec
# Fold complete, fold time: 33.1 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 293521 features
# Feature selection complete, ready for training, elapsed time: 27.1 sec
# Fold complete, fold time: 35.3 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 254473 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 33.1 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 241536 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 33.0 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 236537 features
# Feature selection complete, ready for training, elapsed time: 27.0 sec
# Fold complete, fold time: 33.1 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 252278 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 33.1 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 28, test size: 3 (fract positives in train: 0.464)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 248227 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 32.9 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 28, test size: 3 (fract positives in train: 0.429)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 262316 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 33.3 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 28, test size: 3 (fract positives in train: 0.536)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 279063 features
# Feature selection complete, ready for training, elapsed time: 27.5 sec
# Fold complete, fold time: 34.8 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 28, test size: 3 (fract positives in train: 0.464)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 1.1 sec
# Selecting features using wilcoxon
# Retained 242595 features
# Feature selection complete, ready for training, elapsed time: 27.1 sec
# Fold complete, fold time: 33.4 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE190348_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE111223
# Unable to load requested number of samples, loading entire dataset
# Target label counts (0/1): 131 / 128
# Original labels: ['control' 'case']
# Number of samples: 259
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 233, test size: 26 (fract positives in train: 0.498)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 2.3 sec
# Selecting features using wilcoxon
# Retained 51370 features
# Feature selection complete, ready for training, elapsed time: 16.4 sec
# Fold complete, fold time: 21.1 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 233, test size: 26 (fract positives in train: 0.481)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.1 sec
# Selecting features using wilcoxon
# Retained 49946 features
# Feature selection complete, ready for training, elapsed time: 16.1 sec
# Fold complete, fold time: 20.9 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 233, test size: 26 (fract positives in train: 0.494)
# Imputing missing values, elapsed time: 0.4 sec
# Starting feature selection, elapsed time: 2.4 sec
# Selecting features using wilcoxon
# Retained 57210 features
# Feature selection complete, ready for training, elapsed time: 16.6 sec
# Fold complete, fold time: 21.9 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 233, test size: 26 (fract positives in train: 0.498)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.1 sec
# Selecting features using wilcoxon
# Retained 55287 features
# Feature selection complete, ready for training, elapsed time: 16.2 sec
# Fold complete, fold time: 21.1 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 233, test size: 26 (fract positives in train: 0.502)
# Imputing missing values, elapsed time: 0.4 sec
# Starting feature selection, elapsed time: 3.1 sec
# Selecting features using wilcoxon
# Retained 67960 features
# Feature selection complete, ready for training, elapsed time: 21.6 sec
# Fold complete, fold time: 28.0 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 233, test size: 26 (fract positives in train: 0.489)
# Imputing missing values, elapsed time: 0.4 sec
# Starting feature selection, elapsed time: 2.3 sec
# Selecting features using wilcoxon
# Retained 52075 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 21.1 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 233, test size: 26 (fract positives in train: 0.511)
# Imputing missing values, elapsed time: 0.4 sec
# Starting feature selection, elapsed time: 2.5 sec
# Selecting features using wilcoxon
# Retained 60467 features
# Feature selection complete, ready for training, elapsed time: 17.0 sec
# Fold complete, fold time: 22.6 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 233, test size: 26 (fract positives in train: 0.472)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 41905 features
# Feature selection complete, ready for training, elapsed time: 16.8 sec
# Fold complete, fold time: 20.5 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 233, test size: 26 (fract positives in train: 0.502)
# Imputing missing values, elapsed time: 0.4 sec
# Starting feature selection, elapsed time: 2.4 sec
# Selecting features using wilcoxon
# Retained 53844 features
# Feature selection complete, ready for training, elapsed time: 16.6 sec
# Fold complete, fold time: 21.4 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 234, test size: 25 (fract positives in train: 0.496)
# Imputing missing values, elapsed time: 0.4 sec
# Starting feature selection, elapsed time: 2.4 sec
# Selecting features using wilcoxon
# Retained 57941 features
# Feature selection complete, ready for training, elapsed time: 16.5 sec
# Fold complete, fold time: 22.4 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE111223_l2_cv_res_v0.dat
# ***************************************************************************
#
# CPU times: user 35min 4s, sys: 2min 2s, total: 37min 6s
# Wall time: 41min 10s

# %%
# %%time
datasets_to_analyze = PD_datasets # RA_datasets
PD_CV_results_l2 = {}

for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    # data.load_data() 
    data.load_data(max_samps=600) # For debugging max_CpGs=50000, 
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" 
        penalty = 'l2', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    PD_CV_results_l2[gse_acc] = cv_res
    
    # save results to disk
    out_f = os.path.join(results_d, gse_acc + "_l2_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE145361
# Target label counts (0/1): 287 / 313
# Original labels: ['control' 'case']
# Number of samples: 600
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 540, test size: 60 (fract positives in train: 0.520)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 15.2 sec
# Selecting features using wilcoxon
# Retained 113827 features
# Feature selection complete, ready for training, elapsed time: 106.8 sec
# Fold complete, fold time: 151.3 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 540, test size: 60 (fract positives in train: 0.530)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.7 sec
# Selecting features using wilcoxon
# Retained 106047 features
# Feature selection complete, ready for training, elapsed time: 105.4 sec
# Fold complete, fold time: 149.3 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 540, test size: 60 (fract positives in train: 0.530)
# Imputing missing values, elapsed time: 0.9 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 91479 features
# Feature selection complete, ready for training, elapsed time: 104.9 sec
# Fold complete, fold time: 146.7 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 540, test size: 60 (fract positives in train: 0.517)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 109778 features
# Feature selection complete, ready for training, elapsed time: 105.4 sec
# Fold complete, fold time: 146.3 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 540, test size: 60 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 98365 features
# Feature selection complete, ready for training, elapsed time: 105.4 sec
# Fold complete, fold time: 149.5 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 540, test size: 60 (fract positives in train: 0.522)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 94332 features
# Feature selection complete, ready for training, elapsed time: 105.1 sec
# Fold complete, fold time: 145.6 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 540, test size: 60 (fract positives in train: 0.515)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 106926 features
# Feature selection complete, ready for training, elapsed time: 105.3 sec
# Fold complete, fold time: 150.6 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 540, test size: 60 (fract positives in train: 0.522)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 96658 features
# Feature selection complete, ready for training, elapsed time: 104.9 sec
# Fold complete, fold time: 148.4 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 540, test size: 60 (fract positives in train: 0.522)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 124923 features
# Feature selection complete, ready for training, elapsed time: 105.5 sec
# Fold complete, fold time: 156.3 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 540, test size: 60 (fract positives in train: 0.524)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 106043 features
# Feature selection complete, ready for training, elapsed time: 105.7 sec
# Fold complete, fold time: 150.2 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE145361_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE111629
# Unable to load requested number of samples, loading entire dataset
# Target label counts (0/1): 237 / 334
# Original labels: ['case' 'control']
# Number of samples: 571
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 513, test size: 58 (fract positives in train: 0.579)
# Imputing missing values, elapsed time: 0.6 sec
# Starting feature selection, elapsed time: 9.2 sec
# Selecting features using wilcoxon
# Retained 47921 features
# Feature selection complete, ready for training, elapsed time: 61.1 sec
# Fold complete, fold time: 87.9 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 514, test size: 57 (fract positives in train: 0.586)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.8 sec
# Selecting features using wilcoxon
# Retained 46209 features
# Feature selection complete, ready for training, elapsed time: 50.7 sec
# Fold complete, fold time: 77.5 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 514, test size: 57 (fract positives in train: 0.589)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 44815 features
# Feature selection complete, ready for training, elapsed time: 50.7 sec
# Fold complete, fold time: 77.5 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 514, test size: 57 (fract positives in train: 0.574)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.9 sec
# Selecting features using wilcoxon
# Retained 42573 features
# Feature selection complete, ready for training, elapsed time: 51.5 sec
# Fold complete, fold time: 76.4 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 514, test size: 57 (fract positives in train: 0.593)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 37394 features
# Feature selection complete, ready for training, elapsed time: 50.5 sec
# Fold complete, fold time: 75.0 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 514, test size: 57 (fract positives in train: 0.564)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 47513 features
# Feature selection complete, ready for training, elapsed time: 50.3 sec
# Fold complete, fold time: 77.3 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 514, test size: 57 (fract positives in train: 0.589)
# Imputing missing values, elapsed time: 0.6 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 41083 features
# Feature selection complete, ready for training, elapsed time: 50.7 sec
# Fold complete, fold time: 75.6 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 514, test size: 57 (fract positives in train: 0.591)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 44499 features
# Feature selection complete, ready for training, elapsed time: 50.4 sec
# Fold complete, fold time: 78.8 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 514, test size: 57 (fract positives in train: 0.591)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.7 sec
# Selecting features using wilcoxon
# Retained 43317 features
# Feature selection complete, ready for training, elapsed time: 50.7 sec
# Fold complete, fold time: 78.2 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 514, test size: 57 (fract positives in train: 0.591)
# Imputing missing values, elapsed time: 0.7 sec
# Starting feature selection, elapsed time: 7.8 sec
# Selecting features using wilcoxon
# Retained 44186 features
# Feature selection complete, ready for training, elapsed time: 51.0 sec
# Fold complete, fold time: 77.4 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE111629_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE190348
# Unable to load requested number of samples, loading entire dataset
# Target label counts (0/1): 16 / 15
# Original labels: ['case' 'control']
# Number of samples: 31
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 27, test size: 4 (fract positives in train: 0.444)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 0.9 sec
# Selecting features using wilcoxon
# Retained 263659 features
# Feature selection complete, ready for training, elapsed time: 26.8 sec
# Fold complete, fold time: 56.5 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 293521 features
# Feature selection complete, ready for training, elapsed time: 27.0 sec
# Fold complete, fold time: 56.0 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 254473 features
# Feature selection complete, ready for training, elapsed time: 26.8 sec
# Fold complete, fold time: 53.9 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 241536 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 53.3 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 236537 features
# Feature selection complete, ready for training, elapsed time: 26.8 sec
# Fold complete, fold time: 51.3 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 28, test size: 3 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 252278 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 53.7 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 28, test size: 3 (fract positives in train: 0.464)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 248227 features
# Feature selection complete, ready for training, elapsed time: 27.1 sec
# Fold complete, fold time: 53.9 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 28, test size: 3 (fract positives in train: 0.429)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 262316 features
# Feature selection complete, ready for training, elapsed time: 27.1 sec
# Fold complete, fold time: 56.7 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 28, test size: 3 (fract positives in train: 0.536)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 279063 features
# Feature selection complete, ready for training, elapsed time: 27.4 sec
# Fold complete, fold time: 58.4 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 28, test size: 3 (fract positives in train: 0.464)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 1.0 sec
# Selecting features using wilcoxon
# Retained 242595 features
# Feature selection complete, ready for training, elapsed time: 26.9 sec
# Fold complete, fold time: 55.8 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE190348_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE111223
# Unable to load requested number of samples, loading entire dataset
# Target label counts (0/1): 131 / 128
# Original labels: ['control' 'case']
# Number of samples: 259
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 233, test size: 26 (fract positives in train: 0.498)
# Imputing missing values, elapsed time: 0.2 sec
# Starting feature selection, elapsed time: 2.1 sec
# Selecting features using wilcoxon
# Retained 51370 features
# Feature selection complete, ready for training, elapsed time: 16.2 sec
# Fold complete, fold time: 41.3 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 233, test size: 26 (fract positives in train: 0.481)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 49946 features
# Feature selection complete, ready for training, elapsed time: 16.2 sec
# Fold complete, fold time: 42.1 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 233, test size: 26 (fract positives in train: 0.494)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.3 sec
# Selecting features using wilcoxon
# Retained 57210 features
# Feature selection complete, ready for training, elapsed time: 16.6 sec
# Fold complete, fold time: 44.0 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 233, test size: 26 (fract positives in train: 0.498)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 55287 features
# Feature selection complete, ready for training, elapsed time: 16.2 sec
# Fold complete, fold time: 43.0 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 233, test size: 26 (fract positives in train: 0.502)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.8 sec
# Selecting features using wilcoxon
# Retained 67960 features
# Feature selection complete, ready for training, elapsed time: 21.2 sec
# Fold complete, fold time: 47.1 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 233, test size: 26 (fract positives in train: 0.489)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.1 sec
# Selecting features using wilcoxon
# Retained 52075 features
# Feature selection complete, ready for training, elapsed time: 16.2 sec
# Fold complete, fold time: 41.3 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 233, test size: 26 (fract positives in train: 0.511)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 60467 features
# Feature selection complete, ready for training, elapsed time: 16.7 sec
# Fold complete, fold time: 41.2 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 233, test size: 26 (fract positives in train: 0.472)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 41905 features
# Feature selection complete, ready for training, elapsed time: 16.9 sec
# Fold complete, fold time: 40.6 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 233, test size: 26 (fract positives in train: 0.502)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 53844 features
# Feature selection complete, ready for training, elapsed time: 16.3 sec
# Fold complete, fold time: 38.2 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 234, test size: 25 (fract positives in train: 0.496)
# Imputing missing values, elapsed time: 0.3 sec
# Starting feature selection, elapsed time: 2.2 sec
# Selecting features using wilcoxon
# Retained 57941 features
# Feature selection complete, ready for training, elapsed time: 16.3 sec
# Fold complete, fold time: 42.5 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE111223_l2_cv_res_v0.dat
# ***************************************************************************
#
# CPU times: user 2h 24min 18s, sys: 1h 10min 59s, total: 3h 35min 18s
# Wall time: 55min 24s

# %% [markdown]
# ### Schizophrenia

# %%
Sch_datasets = ["GSE147221"] # ,"GSE41169" data unavailable

# %%
# %%time
datasets_to_analyze = Sch_datasets
Sch_CV_results_l2 = {}

for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    # data.load_data() 
    data.load_data(max_samps=600) # For debugging max_CpGs=50000, 
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" 
        penalty = 'l2', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    Sch_CV_results_l2[gse_acc] = cv_res
    
    # save results to disk
    out_f = os.path.join(results_d, gse_acc + "_l2_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE147221
# Target label counts (0/1): 298 / 302
# Original labels: ['case' 'control']
# Number of samples: 600
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 540, test size: 60 (fract positives in train: 0.502)
# Imputing missing values, elapsed time: 1.1 sec
# Starting feature selection, elapsed time: 14.0 sec
# Selecting features using wilcoxon
# Retained 193289 features
# Feature selection complete, ready for training, elapsed time: 105.1 sec
# Fold complete, fold time: 150.9 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 540, test size: 60 (fract positives in train: 0.511)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 14.0 sec
# Selecting features using wilcoxon
# Retained 194575 features
# Feature selection complete, ready for training, elapsed time: 105.8 sec
# Fold complete, fold time: 157.8 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 540, test size: 60 (fract positives in train: 0.493)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 196569 features
# Feature selection complete, ready for training, elapsed time: 105.9 sec
# Fold complete, fold time: 154.9 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 540, test size: 60 (fract positives in train: 0.509)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 191306 features
# Feature selection complete, ready for training, elapsed time: 106.7 sec
# Fold complete, fold time: 157.1 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 540, test size: 60 (fract positives in train: 0.498)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 193434 features
# Feature selection complete, ready for training, elapsed time: 105.7 sec
# Fold complete, fold time: 155.7 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 540, test size: 60 (fract positives in train: 0.504)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 190373 features
# Feature selection complete, ready for training, elapsed time: 105.4 sec
# Fold complete, fold time: 151.6 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 540, test size: 60 (fract positives in train: 0.513)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 194246 features
# Feature selection complete, ready for training, elapsed time: 105.7 sec
# Fold complete, fold time: 154.4 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 540, test size: 60 (fract positives in train: 0.504)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 192194 features
# Feature selection complete, ready for training, elapsed time: 105.1 sec
# Fold complete, fold time: 147.7 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 540, test size: 60 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.8 sec
# Selecting features using wilcoxon
# Retained 194481 features
# Feature selection complete, ready for training, elapsed time: 105.0 sec
# Fold complete, fold time: 153.1 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 540, test size: 60 (fract positives in train: 0.500)
# Imputing missing values, elapsed time: 1.0 sec
# Starting feature selection, elapsed time: 13.9 sec
# Selecting features using wilcoxon
# Retained 185085 features
# Feature selection complete, ready for training, elapsed time: 105.3 sec
# Fold complete, fold time: 152.4 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE147221_l2_cv_res_v0.dat
# ***************************************************************************
#
# Processing GSE41169
# Unable to load requested number of samples, loading entire dataset
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/dinamo/code/exploration_phase/exploration_v0/microscope.py:57, in Dataset.load_data(self, max_CpGs, max_samps)
#      56 try:
# ---> 57     self.mat = pd.read_csv(os.path.join(self.gse_d, "matrix_beta.tsv"), index_col=0, sep="\t", nrows=max_CpGs, usecols=list(range(max_samps+1)))
#      58 except:
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861 if ioargs.encoding and "b" not in ioargs.mode:
#     862     # Encoding
# --> 863     handle = open(
#     864         handle,
#     865         ioargs.mode,
#     866         encoding=ioargs.encoding,
#     867         errors=errors,
#     868         newline="",
#     869     )
#     870 else:
#     871     # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/erankotler/dinamo/data/gse_data_20231002/GSE41169/matrix_beta.tsv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:9
#
# File ~/dinamo/code/exploration_phase/exploration_v0/microscope.py:60, in Dataset.load_data(self, max_CpGs, max_samps)
#      58     except:
#      59         print("Unable to load requested number of samples, loading entire dataset")
# ---> 60         self.mat = pd.read_csv(os.path.join(self.gse_d, "matrix_beta.tsv"), index_col=0, sep="\t", nrows=max_CpGs)
#      62 if "ID_REF" in self.mat.columns: # fix for datasets where ID_REF is loaded as a column
#      63     self.mat.index = self.mat["ID_REF"]
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniconda3/envs/geo_cpg/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/erankotler/dinamo/data/gse_data_20231002/GSE41169/matrix_beta.tsv'

# %%
# %%time
datasets_to_analyze = Sch_datasets
Sch_CV_results_l1 = {}

for gse_acc in datasets_to_analyze:
    print("Processing", gse_acc)
    gse_d = os.path.join(data_d, gse_acc)
    data = mc.Dataset(gse_d=gse_d)
    data.load_data() 
    # data.load_data(max_samps=600) # For debugging max_CpGs=50000, 
    data.organize_data()
    
    # Examine original label names
    print("Original labels:", data.orig_label_names)
    print("Number of samples:", data.df.shape[0])
    
    cv_res = mc.cv_train_test(
        data, 
        CV = 10, # "LOO" 
        penalty = 'l1', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection='wilcox',
        feat_selection_pval_thresh=0.05)

    Sch_CV_results_l2[gse_acc] = cv_res
    
    # save results to disk
    out_f = os.path.join(results_d, gse_acc + "_l1_cv_res_v0.dat")
    pickle.dump(cv_res, open(out_f, 'wb'))
    print ("CV results saved to", out_f)
    print("***************************************************************************\n")
# Out:
# Processing GSE147221
# Target label counts (0/1): 331 / 348
# Original labels: ['case' 'control']
# Number of samples: 679
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 611, test size: 68 (fract positives in train: 0.509)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.6 sec
# Selecting features using wilcoxon
# Retained 207429 features
# Feature selection complete, ready for training, elapsed time: 111.0 sec
# Fold complete, fold time: 156.1 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 611, test size: 68 (fract positives in train: 0.520)
# Imputing missing values, elapsed time: 1.4 sec
# Starting feature selection, elapsed time: 8.7 sec
# Selecting features using wilcoxon
# Retained 214589 features
# Feature selection complete, ready for training, elapsed time: 112.1 sec
# Fold complete, fold time: 157.8 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 611, test size: 68 (fract positives in train: 0.511)
# Imputing missing values, elapsed time: 1.1 sec
# Starting feature selection, elapsed time: 8.5 sec
# Selecting features using wilcoxon
# Retained 222257 features
# Feature selection complete, ready for training, elapsed time: 111.6 sec
# Fold complete, fold time: 159.7 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 611, test size: 68 (fract positives in train: 0.511)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.7 sec
# Selecting features using wilcoxon
# Retained 215285 features
# Feature selection complete, ready for training, elapsed time: 111.6 sec
# Fold complete, fold time: 157.0 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 611, test size: 68 (fract positives in train: 0.514)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.7 sec
# Selecting features using wilcoxon
# Retained 208671 features
# Feature selection complete, ready for training, elapsed time: 111.6 sec
# Fold complete, fold time: 155.8 sec
# Starting fold 5 - Train-test splitting
# CV fold 5 Train size: 611, test size: 68 (fract positives in train: 0.507)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.7 sec
# Selecting features using wilcoxon
# Retained 213946 features
# Feature selection complete, ready for training, elapsed time: 112.1 sec
# Fold complete, fold time: 158.4 sec
# Starting fold 6 - Train-test splitting
# CV fold 6 Train size: 611, test size: 68 (fract positives in train: 0.502)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.6 sec
# Selecting features using wilcoxon
# Retained 209290 features
# Feature selection complete, ready for training, elapsed time: 111.7 sec
# Fold complete, fold time: 155.3 sec
# Starting fold 7 - Train-test splitting
# CV fold 7 Train size: 611, test size: 68 (fract positives in train: 0.530)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.7 sec
# Selecting features using wilcoxon
# Retained 209943 features
# Feature selection complete, ready for training, elapsed time: 111.6 sec
# Fold complete, fold time: 154.1 sec
# Starting fold 8 - Train-test splitting
# CV fold 8 Train size: 611, test size: 68 (fract positives in train: 0.512)
# Imputing missing values, elapsed time: 1.2 sec
# Starting feature selection, elapsed time: 8.7 sec
# Selecting features using wilcoxon
# Retained 214711 features
# Feature selection complete, ready for training, elapsed time: 114.1 sec
# Fold complete, fold time: 159.6 sec
# Starting fold 9 - Train-test splitting
# CV fold 9 Train size: 612, test size: 67 (fract positives in train: 0.508)
# Imputing missing values, elapsed time: 1.3 sec
# Starting feature selection, elapsed time: 8.8 sec
# Selecting features using wilcoxon
# Retained 202998 features
# Feature selection complete, ready for training, elapsed time: 114.3 sec
# Fold complete, fold time: 158.3 sec
# ----CV complete----
# CV results saved to /Users/erankotler/dinamo/resutls/GSE147221_l1_cv_res_v0.dat
# ***************************************************************************
#
# CPU times: user 19min 37s, sys: 47.9 s, total: 20min 25s
# Wall time: 26min 32s

# %% [markdown]
# # --- END OF NOTEBOOK ---

# %% [markdown]
# #### TO DO - Rerun PD with entire data

# %% [markdown]
# ### Debugging stuff

# %%
gse_acc = "GSE121192"
gse_d = os.path.join(data_d, gse_acc)
data = mc.Dataset(gse_d=gse_d)
data.load_data(max_CpGs=50000)#, max_samps=50) 
data.organize_data()
# Out:
# Target label counts (0/1): 16 / 30

# %%
data.y.value_counts()
# Out:
# 1.0    30
# 0.0    16
# Name: count, dtype: int64

# %%
data.df.head()
# Out:
#             cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# GSM3427639    0.489674    0.970901    0.934324    0.167923    0.807739
# GSM3427625    0.783458         NaN         NaN         NaN         NaN
# GSM3427626    0.769447    0.972417    0.906328    0.396645    0.939122
# GSM3427644    0.581425    0.969801    0.940581    0.232248    0.740743
# GSM3427635    0.486887    0.970310    0.949697    0.207570    0.707721
#
#             cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# GSM3427639    0.817810    0.853751    0.224321    0.345042    0.017054  ...
# GSM3427625         NaN    0.868898    0.283165    0.417663    0.014139  ...
# GSM3427626    0.789392    0.902351    0.383123    0.383661    0.015736  ...
# GSM3427644    0.782575    0.875173    0.335452    0.432475    0.015218  ...
# GSM3427635    0.790012    0.811613    0.209522    0.337576    0.013981  ...
#
#             cg02455797  cg02455803  cg02455820  cg02455827  cg02455836  \
# GSM3427639    0.833061    0.020768    0.112676    0.879540    0.983849
# GSM3427625    0.878493    0.025093    0.096117    0.898236    0.984983
# GSM3427626    0.781869    0.027404    0.169894    0.880735    0.986625
# GSM3427644    0.806722    0.025398    0.126842    0.876903    0.987728
# GSM3427635    0.783549    0.028175    0.107436    0.879318    0.987014
#
#             cg02455868  cg02456087  cg02456218  cg02456219  cg02456226
# GSM3427639    0.922799    0.120537    0.859151    0.057736    0.035534
# GSM3427625         NaN    0.254438         NaN    0.068643    0.166669
# GSM3427626    0.952526    0.169433    0.840767    0.043526    0.178105
# GSM3427644    0.917339    0.131432    0.876083    0.052380    0.037209
# GSM3427635    0.936205    0.111144    0.932020    0.058921    0.045682
#
# [5 rows x 50000 columns]

# %%
data.df_filt = data.df.dropna(axis=1)

# %%
data.df_filt.shape
# Out:
# (46, 32417)

# %%
data.X = data.df_filt.values

# %%
data.X.shape, data.y.shape
# Out:
# ((46, 32417), (46,))

# %%
data.y.head()
# Out:
# GSM3427639    1.0
# GSM3427625    1.0
# GSM3427626    1.0
# GSM3427644    1.0
# GSM3427635    0.0
# dtype: float64

# %%
data.df.head()
# Out:
#             cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# GSM3427639    0.489674    0.970901    0.934324    0.167923    0.807739
# GSM3427625    0.783458         NaN         NaN         NaN         NaN
# GSM3427626    0.769447    0.972417    0.906328    0.396645    0.939122
# GSM3427644    0.581425    0.969801    0.940581    0.232248    0.740743
# GSM3427635    0.486887    0.970310    0.949697    0.207570    0.707721
#
#             cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# GSM3427639    0.817810    0.853751    0.224321    0.345042    0.017054  ...
# GSM3427625         NaN    0.868898    0.283165    0.417663    0.014139  ...
# GSM3427626    0.789392    0.902351    0.383123    0.383661    0.015736  ...
# GSM3427644    0.782575    0.875173    0.335452    0.432475    0.015218  ...
# GSM3427635    0.790012    0.811613    0.209522    0.337576    0.013981  ...
#
#             cg02455797  cg02455803  cg02455820  cg02455827  cg02455836  \
# GSM3427639    0.833061    0.020768    0.112676    0.879540    0.983849
# GSM3427625    0.878493    0.025093    0.096117    0.898236    0.984983
# GSM3427626    0.781869    0.027404    0.169894    0.880735    0.986625
# GSM3427644    0.806722    0.025398    0.126842    0.876903    0.987728
# GSM3427635    0.783549    0.028175    0.107436    0.879318    0.987014
#
#             cg02455868  cg02456087  cg02456218  cg02456219  cg02456226
# GSM3427639    0.922799    0.120537    0.859151    0.057736    0.035534
# GSM3427625         NaN    0.254438         NaN    0.068643    0.166669
# GSM3427626    0.952526    0.169433    0.840767    0.043526    0.178105
# GSM3427644    0.917339    0.131432    0.876083    0.052380    0.037209
# GSM3427635    0.936205    0.111144    0.932020    0.058921    0.045682
#
# [5 rows x 50000 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, LeaveOneOut, train_test_split
from sklearn.linear_model import LogisticRegressionCV

# %%
X_train, X_test, y_train, y_test = train_test_split(data.X, data.y, test_size=0.2, random_state=44)

# %%
X_train.shape, X_test.shape
# Out:
# ((36, 32417), (10, 32417))

# %%
clf = LogisticRegressionCV(cv=3, max_iter=1000, penalty='l2')

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(cv=3, max_iter=1000)

# %%
clf.Cs_
# Out:
# array([1.00000000e-04, 7.74263683e-04, 5.99484250e-03, 4.64158883e-02,
#        3.59381366e-01, 2.78255940e+00, 2.15443469e+01, 1.66810054e+02,
#        1.29154967e+03, 1.00000000e+04])

# %%
clf.C_
# Out:
# array([2.7825594])

# %%
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.91217269, 0.87903408, 0.92292885, 0.82579103, 0.95356712,
#        0.939055  , 0.93522591, 0.99236006, 0.32852942, 0.94901905])

# %%
y_test.value_counts()
# Out:
# 1.0    9
# 0.0    1
# Name: count, dtype: int64

# %%
sns.stripplot(data=pd.DataFrame({"label":y_test, "pred_prob":y_pred_prob}),
                x="label", y="pred_prob", s=3)
# Out:
# <Axes: xlabel='label', ylabel='pred_prob'>

# %%
rep = classification_report(y_test, y_pred > 0.5)
print(rep)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         9
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %%
cv_res = mc.cv_train_test(
        data, 
        CV = 5, # "LOO" # 10 #"LOO"
        penalty = 'l2', #None, #'l2', 
        internalCV_folds = 3,
        nan_policy="impute_by_median",
        feat_selection=None,#'wilcox',
        feat_selection_pval_thresh=0.05)
# Out:
# Starting cross validation
# Starting fold 0 - Train-test splitting
# CV fold 0 Train size: 36, test size: 10 (fract positives in train: 0.611)
# Imputing missing values, elapsed time: 0.0 sec
# Starting feature selection, elapsed time: 0.1 sec
# Retained 34309 features
# Feature selection complete, ready for training, elapsed time: 0.1 sec
# LogisticRegressionCV(class_weight='balanced', cv=3, max_iter=300,
#                      random_state=42)
# Fold complete, fold time: 12.3 sec
# Starting fold 1 - Train-test splitting
# CV fold 1 Train size: 37, test size: 9 (fract positives in train: 0.676)
# Imputing missing values, elapsed time: 0.0 sec
# Starting feature selection, elapsed time: 0.1 sec
# Retained 33388 features
# Feature selection complete, ready for training, elapsed time: 0.1 sec
# LogisticRegressionCV(class_weight='balanced', cv=3, max_iter=300,
#                      random_state=42)
# Fold complete, fold time: 12.8 sec
# Starting fold 2 - Train-test splitting
# CV fold 2 Train size: 37, test size: 9 (fract positives in train: 0.676)
# Imputing missing values, elapsed time: 0.0 sec
# Starting feature selection, elapsed time: 0.1 sec
# Retained 32422 features
# Feature selection complete, ready for training, elapsed time: 0.1 sec
# LogisticRegressionCV(class_weight='balanced', cv=3, max_iter=300,
#                      random_state=42)
# Fold complete, fold time: 13.2 sec
# Starting fold 3 - Train-test splitting
# CV fold 3 Train size: 37, test size: 9 (fract positives in train: 0.676)
# Imputing missing values, elapsed time: 0.0 sec
# Starting feature selection, elapsed time: 0.1 sec
# Retained 32421 features
# Feature selection complete, ready for training, elapsed time: 0.1 sec
# LogisticRegressionCV(class_weight='balanced', cv=3, max_iter=300,
#                      random_state=42)
# Fold complete, fold time: 13.6 sec
# Starting fold 4 - Train-test splitting
# CV fold 4 Train size: 37, test size: 9 (fract positives in train: 0.622)
# Imputing missing values, elapsed time: 0.0 sec
# Starting feature selection, elapsed time: 0.1 sec
# Retained 32426 features
# Feature selection complete, ready for training, elapsed time: 0.2 sec
# LogisticRegressionCV(class_weight='balanced', cv=3, max_iter=300,
#                      random_state=42)
# Fold complete, fold time: 13.1 sec
# ----CV complete----

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score

# %%
SelectKBest(
cross_val_score(
